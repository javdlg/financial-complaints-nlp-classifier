# %% [markdown]
# # Text Preprocessing Pipeline

# %% [markdown]
# ## 1. Setup & Imports

# %%
import pandas as pd
import sys
import os
from tqdm import tqdm # Progress bar for long operations

# Add the project root to system path to import from 'src'
sys.path.append(os.path.abspath('..'))

from src.preprocessing import clean_text

# 1. Load the consolidated raw dataset (The Big 5 Classes)
# We use the file we saved in the previous notebook
input_path = '../data/raw/complaints_5_classes_raw.csv'

print("⏳ Loading raw consolidated data...")
df = pd.read_csv(input_path)

# Safety check: Ensure no nulls slipped in
df = df.dropna(subset=['text', 'target'])

print(f"✅ Data Loaded. Shape: {df.shape}")
print(f"Columns: {df.columns.tolist()}")
# Out:
# ✅ SpaCy model 'en_core_web_sm' loaded successfully.
# ⏳ Loading raw consolidated data...
# ✅ Data Loaded. Shape: (333096, 2)
# Columns: ['text', 'target']

# %% [markdown]
# ## 2. Sampling

# %%
# UNCOMMENT THIS if you want a faster run for testing (e.g., 50k rows)
# df = df.sample(n=50000, random_state=42)
# print(f"Sampled down to: {df.shape}")

# %% [markdown]
# ## 3. Processing

# %%
# Register pandas with tqdm to enable the 'progress_apply' function
tqdm.pandas()

print("---------------------------------------------------------")
print("⏳ Starting NLP Preprocessing Pipeline...")
print("   - Lowercasing")
print("   - Removing 'XXXX' anonymization masks")
print("   - Removing URLs/HTML")
print("   - SpaCy Lemmatization & Stopword Removal")
print("---------------------------------------------------------")

# Apply the cleaning function with a progress bar
df['processed_text'] = df['text'].progress_apply(clean_text)

print("\n✅ Preprocessing complete!")
# Out:
# ---------------------------------------------------------
# ⏳ Starting NLP Preprocessing Pipeline...
#    - Lowercasing
#    - Removing 'XXXX' anonymization masks
#    - Removing URLs/HTML
#    - SpaCy Lemmatization & Stopword Removal
# ---------------------------------------------------------
# 100%|██████████| 333096/333096 [4:58:51<00:00, 18.58it/s]
# ✅ Preprocessing complete!

# %% [markdown]
# ## 4. Final Quality Check and Save

# %%
# Remove rows that became empty after cleaning
# (e.g., a complaint that was just "XXXX XXXX" would become empty)
initial_count = len(df)
df_final = df[df['processed_text'].str.len() > 1]
dropped_count = initial_count - len(df_final)

print(f"Rows dropped (empty after cleaning): {dropped_count}")
print(f"Final rows for modeling: {len(df_final)}")

# Save to processed folder
output_path = '../data/processed/complaints_processed.csv'
df_final.to_csv(output_path, index=False)

print(f"💾 Processed dataset saved to: {output_path}")

# Show a random sample to verify quality
print("\n--- Cleaning Sample (Before vs After) ---")
sample = df_final.sample(20, random_state=42)  # Show 20 random samples
for index, row in sample.iterrows():
    print(f"ORIGINAL: {row['text'][:100]}...")
    print(f"CLEANED:  {row['processed_text'][:100]}...")
    print("-" * 50)
# Out:
# Rows dropped (empty after cleaning): 24
# Final rows for modeling: 333072
# 💾 Processed dataset saved to: ../data/processed/complaints_processed.csv
#
# --- Cleaning Sample (Before vs After) ---
# ORIGINAL: This company has been constantly calling my home for the last XXXX yrs all through out the day. The ...
# CLEANED:  company constantly call home yrs day everyday afternoon ask respond numerous time let know person pe...
# --------------------------------------------------
# ORIGINAL: I was walking through the XXXX XXXX in XXXX, Ohio and was passing by the Kay Jewelers store. A Kay J...
# CLEANED:  walk ohio pass kay jeweler store kay jeweler employee ask pass say say need signature day meet goal ...
# --------------------------------------------------
# ORIGINAL: Amount was paid in full in 2014 but still appear on credit report plz remove...
# CLEANED:  pay appear credit report plz remove...
# --------------------------------------------------
# ORIGINAL: I have been conversing with SunTrust Bank regarding an unethical fee they charged my account. Now th...
# CLEANED:  converse suntrust bank unethical fee charge account state incorrectly give refund remove account rec...
# --------------------------------------------------
# ORIGINAL: Chase contacted a family member through a phone number listed on my XXXX account. Chase claimed the ...
# CLEANED:  chase contact family member phone number list account chase claim number file account information li...
# --------------------------------------------------
# ORIGINAL: I requested for the following information more than four weeks ago without a response from the Trust...
# CLEANED:  request follow information week ago response trustee respect document associate sale house point hig...
# --------------------------------------------------
# ORIGINAL: THIS IS IN RELATIONSHIP TO COMPLAINT # XXXX THAT WAS FILED ON XXXX/XXXX/XXXX. THIS WAS FILE AGAINST ...
# CLEANED:  relationship complaint file file authorization look information credit profile send letter company a...
# --------------------------------------------------
# ORIGINAL: Two 30-day late mortgage past due payments that were directly caused from Wells Fargo website malfun...
# CLEANED:  day late mortgage past payment directly cause wells fargo website malfunctioning mortgage wells farg...
# --------------------------------------------------
# ORIGINAL: I believe this is a collection company which I have already spoken with about a debt, they are conti...
# CLEANED:  believe collection company speak debt continue multiple time day home cell phone ask stop call cell ...
# --------------------------------------------------
# ORIGINAL: The credit company XXXX XXXX requested a copy of my credit report without my permission. The request...
# CLEANED:  credit company request copy credit report permission request contact request authorization...
# --------------------------------------------------
# ORIGINAL: The Loan Estimate ( Good Faith Estimate ) disclosed estimated property taxes for the LENDER ESTABLIS...
# CLEANED:  loan estimate good faith estimate disclose estimate property taxis lender establish escrow period co...
# --------------------------------------------------
# ORIGINAL: DNA has called my cell phone saying I have a debt, and to please contact them. I called to be told b...
# CLEANED:  dna call cell phone say debt contact call tell recording attempt collect debt later hear representat...
# --------------------------------------------------
# ORIGINAL: The account was paid in full and agreed to be removed from my credit history. However the account st...
# CLEANED:  account pay agree remove credit history account remain remove ar place collection responsibility ind...
# --------------------------------------------------
# ORIGINAL: I am having an issue with XXXX and XXXX in disputing incorrect information on my credit reports. Tod...
# CLEANED:  have issue dispute incorrect information credit report today view look like problem solve delete rep...
# --------------------------------------------------
# ORIGINAL: I set up direct deposit of my XXXX XXXX  Payment with XXXX XXXX for the first time. This was to star...
# CLEANED:  set direct deposit payment time start advise approx week prior update address go person lease etc se...
# --------------------------------------------------
# ORIGINAL: My clients property is underwater m y 1st question  is can he do a short sale if he is still making ...
# CLEANED:  client property underwater st question short sale make payment offer property attach document...
# --------------------------------------------------
# ORIGINAL: I received a collection call a few months ago claiming I had a debt in collections. I immediately th...
# CLEANED:  receive collection month ago claim debt collection immediately think scam sound sketchy especially r...
# --------------------------------------------------
# ORIGINAL: XXXX XXXX Capital one will not remove this account and it has been fully paid...
# CLEANED:  capital remove account fully pay...
# --------------------------------------------------
# ORIGINAL: I submitted a request for PMI Waiver on XXXX XXXX, XXXX to Loan Care, LLC. I was told I would be con...
# CLEANED:  submit request pmi waiver loan care llc tell contact business day follow numerous time email phone c...
# --------------------------------------------------
# ORIGINAL: I filed a dispute online, but received no confirmation number or email confirmation. I subsequently ...
# CLEANED:  file dispute online receive confirmation number email confirmation subsequently try check status dis...
# --------------------------------------------------
